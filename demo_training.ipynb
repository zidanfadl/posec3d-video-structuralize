# %% [markdown]
# ## Training from bash

# %%
# !python mmaction2/tools/train.py mmaction2/configs/skeleton/posec3d/ciis_not-multi.py \
    --work-dir work_dirs/temp \
    --seed 0 \
    --resume
# Out:
# 05/09 08:39:53 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.18 (default, Sep 11 2023, 13:40:15) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce GTX 1650 Ti
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.3, V12.3.107
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 2.1.2+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.2, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.2
#     OpenCV: 4.9.0
#     MMEngine: 0.10.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     diff_rank_seed: False
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 05/09 08:39:53 - mmengine - INFO - Config:
# ann_file = 'data/skeleton/ciis_0s7_v1.pkl'
# dataset_type = 'PoseDataset'
# default_hooks = dict(
#     checkpoint=dict(interval=5, save_best='auto', type='CheckpointHook'),
#     logger=dict(ignore_last=False, interval=10000, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     runtime_info=dict(type='RuntimeInfoHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffers=dict(type='SyncBuffersHook'),
#     timer=dict(type='IterTimerHook'))
# default_scope = 'mmaction'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# left_kp = [
#     1,
#     3,
#     5,
#     7,
#     9,
#     11,
#     13,
#     15,
# ]
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)
# model = dict(
#     backbone=dict(
#         base_channels=32,
#         conv1_stride_s=1,
#         depth=50,
#         dilations=(
#             1,
#             1,
#             1,
#         ),
#         in_channels=17,
#         inflate=(
#             0,
#             1,
#             1,
#         ),
#         num_stages=3,
#         out_indices=(2, ),
#         pool1_stride_s=1,
#         spatial_strides=(
#             2,
#             2,
#             2,
#         ),
#         stage_blocks=(
#             4,
#             6,
#             3,
#         ),
#         temporal_strides=(
#             1,
#             1,
#             2,
#         ),
#         type='ResNet3dSlowOnly'),
#     cls_head=dict(
#         average_clips='prob',
#         dropout_ratio=0.5,
#         in_channels=512,
#         num_classes=10,
#         type='I3DHead'),
#     type='Recognizer3D')
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=40, norm_type=2),
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.003))
# param_scheduler = [
#     dict(
#         T_max=30,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         eta_min=0,
#         type='CosineAnnealingLR'),
# ]
# randomness = dict(deterministic=False, diff_rank_seed=False, seed=0)
# resume = True
# right_kp = [
#     2,
#     4,
#     6,
#     8,
#     10,
#     12,
#     14,
#     16,
# ]
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='data/skeleton/ciis_0s7_v1.pkl',
#         pipeline=[
#             dict(type='PoseDecode'),
#             dict(allow_imgpad=True, hw_ratio=1.0, type='PoseCompact'),
#             dict(scale=(
#                 -1,
#                 64,
#             ), type='Resize'),
#             dict(crop_size=64, type='CenterCrop'),
#             dict(
#                 double=True,
#                 left_kp=[
#                     1,
#                     3,
#                     5,
#                     7,
#                     9,
#                     11,
#                     13,
#                     15,
#                 ],
#                 right_kp=[
#                     2,
#                     4,
#                     6,
#                     8,
#                     10,
#                     12,
#                     14,
#                     16,
#                 ],
#                 sigma=0.6,
#                 type='GeneratePoseTarget',
#                 use_score=True,
#                 with_kp=True,
#                 with_limb=False),
#             dict(input_format='NCTHW_Heatmap', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         split='xsub_val',
#         test_mode=True,
#         type='PoseDataset'),
#     num_workers=1,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(type='AccMetric')
# test_pipeline = [
#     dict(type='PoseDecode'),
#     dict(allow_imgpad=True, hw_ratio=1.0, type='PoseCompact'),
#     dict(scale=(
#         -1,
#         64,
#     ), type='Resize'),
#     dict(crop_size=64, type='CenterCrop'),
#     dict(
#         double=True,
#         left_kp=[
#             1,
#             3,
#             5,
#             7,
#             9,
#             11,
#             13,
#             15,
#         ],
#         right_kp=[
#             2,
#             4,
#             6,
#             8,
#             10,
#             12,
#             14,
#             16,
#         ],
#         sigma=0.6,
#         type='GeneratePoseTarget',
#         use_score=True,
#         with_kp=True,
#         with_limb=False),
#     dict(input_format='NCTHW_Heatmap', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# train_cfg = dict(
#     max_epochs=30, type='EpochBasedTrainLoop', val_begin=5, val_interval=5)
# train_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='data/skeleton/ciis_0s7_v1.pkl',
#         pipeline=[
#             dict(type='PoseDecode'),
#             dict(allow_imgpad=True, hw_ratio=1.0, type='PoseCompact'),
#             dict(scale=(
#                 -1,
#                 64,
#             ), type='Resize'),
#             dict(area_range=(
#                 0.56,
#                 1.0,
#             ), type='RandomResizedCrop'),
#             dict(keep_ratio=False, scale=(
#                 56,
#                 56,
#             ), type='Resize'),
#             dict(
#                 flip_ratio=0.5,
#                 left_kp=[
#                     1,
#                     3,
#                     5,
#                     7,
#                     9,
#                     11,
#                     13,
#                     15,
#                 ],
#                 right_kp=[
#                     2,
#                     4,
#                     6,
#                     8,
#                     10,
#                     12,
#                     14,
#                     16,
#                 ],
#                 type='Flip'),
#             dict(
#                 sigma=0.6,
#                 type='GeneratePoseTarget',
#                 use_score=True,
#                 with_kp=True,
#                 with_limb=False),
#             dict(input_format='NCTHW_Heatmap', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         split='xsub_train',
#         type='PoseDataset'),
#     num_workers=1,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='PoseDecode'),
#     dict(allow_imgpad=True, hw_ratio=1.0, type='PoseCompact'),
#     dict(scale=(
#         -1,
#         64,
#     ), type='Resize'),
#     dict(area_range=(
#         0.56,
#         1.0,
#     ), type='RandomResizedCrop'),
#     dict(keep_ratio=False, scale=(
#         56,
#         56,
#     ), type='Resize'),
#     dict(
#         flip_ratio=0.5,
#         left_kp=[
#             1,
#             3,
#             5,
#             7,
#             9,
#             11,
#             13,
#             15,
#         ],
#         right_kp=[
#             2,
#             4,
#             6,
#             8,
#             10,
#             12,
#             14,
#             16,
#         ],
#         type='Flip'),
#     dict(
#         sigma=0.6,
#         type='GeneratePoseTarget',
#         use_score=True,
#         with_kp=True,
#         with_limb=False),
#     dict(input_format='NCTHW_Heatmap', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='data/skeleton/ciis_0s7_v1.pkl',
#         pipeline=[
#             dict(type='PoseDecode'),
#             dict(allow_imgpad=True, hw_ratio=1.0, type='PoseCompact'),
#             dict(scale=(
#                 -1,
#                 64,
#             ), type='Resize'),
#             dict(crop_size=64, type='CenterCrop'),
#             dict(
#                 sigma=0.6,
#                 type='GeneratePoseTarget',
#                 use_score=True,
#                 with_kp=True,
#                 with_limb=False),
#             dict(input_format='NCTHW_Heatmap', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         split='xsub_val',
#         test_mode=True,
#         type='PoseDataset'),
#     num_workers=1,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(type='AccMetric')
# val_pipeline = [
#     dict(type='PoseDecode'),
#     dict(allow_imgpad=True, hw_ratio=1.0, type='PoseCompact'),
#     dict(scale=(
#         -1,
#         64,
#     ), type='Resize'),
#     dict(crop_size=64, type='CenterCrop'),
#     dict(
#         sigma=0.6,
#         type='GeneratePoseTarget',
#         use_score=True,
#         with_kp=True,
#         with_limb=False),
#     dict(input_format='NCTHW_Heatmap', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='ActionVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = 'work_dirs/temp'
#
# 05/09 08:39:55 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 05/09 08:39:55 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 05/09 08:39:55 - mmengine - INFO - 4005 videos remain after valid thresholding
# 05/09 08:39:55 - mmengine - INFO - 1703 videos remain after valid thresholding
# Did not find last_checkpoint to be resumed.
# 05/09 08:39:55 - mmengine - INFO - Auto resumed from the latest checkpoint None.
# 05/09 08:39:55 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 05/09 08:39:55 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 05/09 08:39:55 - mmengine - INFO - Checkpoints will be saved to /home/aldy/Documents/skripsi/posec3d-video-structuralize/work_dirs/temp.
# 05/09 08:40:25 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:40:54 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:41:24 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:41:54 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:41:54 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:41:54 - mmengine - INFO - Epoch(train)  [1][4005/4005]  lr: 9.9726e-03  eta: 0:57:21  time: 0.0295  data_time: 0.0017  memory: 212  grad_norm: 1.4531  loss: 0.5714  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.5714
# 05/09 08:42:23 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:42:53 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:43:22 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:43:52 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:43:52 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:43:52 - mmengine - INFO - Epoch(train)  [2][4005/4005]  lr: 9.8908e-03  eta: 0:55:17  time: 0.0299  data_time: 0.0015  memory: 212  grad_norm: 1.2962  loss: 0.6121  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.6121
# 05/09 08:44:23 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:44:53 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:45:23 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:45:53 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:45:53 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:45:53 - mmengine - INFO - Epoch(train)  [3][4005/4005]  lr: 9.7553e-03  eta: 0:53:35  time: 0.0296  data_time: 0.0016  memory: 212  grad_norm: 0.4864  loss: 0.7558  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.7558
# 05/09 08:46:22 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:46:52 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:47:22 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:47:53 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:47:54 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:47:54 - mmengine - INFO - Epoch(train)  [4][4005/4005]  lr: 9.5678e-03  eta: 0:51:45  time: 0.0317  data_time: 0.0020  memory: 212  grad_norm: 0.4553  loss: 0.7627  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.7627
# 05/09 08:48:23 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:48:53 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:49:23 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:49:53 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:49:54 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:49:54 - mmengine - INFO - Epoch(train)  [5][4005/4005]  lr: 9.3302e-03  eta: 0:49:49  time: 0.0315  data_time: 0.0019  memory: 212  grad_norm: 0.4551  loss: 0.7699  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.7699
# 05/09 08:49:54 - mmengine - INFO - Saving checkpoint at 5 epochs
# 05/09 08:50:19 - mmengine - INFO - Epoch(val) [5][1703/1703]    acc/top1: 0.5208  acc/top5: 0.7598  acc/mean1: 0.1000  data_time: 0.0013  time: 0.0143
# 05/09 08:50:19 - mmengine - INFO - The best checkpoint with 0.5208 acc/top1 at 5 epoch is saved to best_acc_top1_epoch_5.pth.
# 05/09 08:50:49 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:51:19 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:51:49 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:52:20 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:52:21 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:52:21 - mmengine - INFO - Epoch(train)  [6][4005/4005]  lr: 9.0452e-03  eta: 0:47:56  time: 0.0301  data_time: 0.0018  memory: 212  grad_norm: 0.4550  loss: 0.7788  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.7788
# 05/09 08:52:49 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:53:19 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:53:49 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:54:19 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:54:20 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:54:20 - mmengine - INFO - Epoch(train)  [7][4005/4005]  lr: 8.7158e-03  eta: 0:45:55  time: 0.0295  data_time: 0.0017  memory: 212  grad_norm: 0.4552  loss: 0.7896  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.7896
# 05/09 08:54:49 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:55:19 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:55:50 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:56:19 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:56:21 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:56:21 - mmengine - INFO - Epoch(train)  [8][4005/4005]  lr: 8.3458e-03  eta: 0:43:55  time: 0.0311  data_time: 0.0021  memory: 212  grad_norm: 0.4556  loss: 0.8021  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.8021
# 05/09 08:56:49 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:57:20 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:57:51 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:58:21 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:58:23 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:58:23 - mmengine - INFO - Epoch(train)  [9][4005/4005]  lr: 7.9390e-03  eta: 0:42:00  time: 0.0310  data_time: 0.0020  memory: 212  grad_norm: 0.4566  loss: 0.8166  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.8166
# 05/09 08:58:52 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:59:22 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 08:59:53 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:00:23 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:00:25 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:00:25 - mmengine - INFO - Epoch(train) [10][4005/4005]  lr: 7.5001e-03  eta: 0:40:03  time: 0.0303  data_time: 0.0018  memory: 212  grad_norm: 0.4582  loss: 0.8329  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.8329
# 05/09 09:00:25 - mmengine - INFO - Saving checkpoint at 10 epochs
# 05/09 09:00:49 - mmengine - INFO - Epoch(val) [10][1703/1703]    acc/top1: 0.5208  acc/top5: 0.7598  acc/mean1: 0.1000  data_time: 0.0012  time: 0.0139
# 05/09 09:01:18 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:01:49 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:02:19 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:02:50 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:02:51 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:02:51 - mmengine - INFO - Epoch(train) [11][4005/4005]  lr: 7.0338e-03  eta: 0:38:06  time: 0.0297  data_time: 0.0018  memory: 212  grad_norm: 0.4606  loss: 0.8512  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.8512
# 05/09 09:03:20 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:03:50 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:04:21 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:04:51 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:04:53 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:04:53 - mmengine - INFO - Epoch(train) [12][4005/4005]  lr: 6.5452e-03  eta: 0:36:07  time: 0.0311  data_time: 0.0020  memory: 212  grad_norm: 0.4642  loss: 0.8713  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.8713
# 05/09 09:05:22 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:05:52 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:06:23 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:06:53 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:06:55 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:06:55 - mmengine - INFO - Epoch(train) [13][4005/4005]  lr: 6.0397e-03  eta: 0:34:08  time: 0.0302  data_time: 0.0017  memory: 212  grad_norm: 0.4691  loss: 0.8932  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.8932
# 05/09 09:07:23 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:07:54 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:08:24 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:08:55 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:08:57 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:08:57 - mmengine - INFO - Epoch(train) [14][4005/4005]  lr: 5.5228e-03  eta: 0:32:08  time: 0.0301  data_time: 0.0016  memory: 212  grad_norm: 0.4756  loss: 0.9169  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.9169
# 05/09 09:09:25 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:09:55 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:10:26 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:10:56 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:10:59 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:10:59 - mmengine - INFO - Epoch(train) [15][4005/4005]  lr: 5.0001e-03  eta: 0:30:08  time: 0.0315  data_time: 0.0020  memory: 212  grad_norm: 0.4843  loss: 0.9424  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.9424
# 05/09 09:10:59 - mmengine - INFO - Saving checkpoint at 15 epochs
# 05/09 09:11:23 - mmengine - INFO - Epoch(val) [15][1703/1703]    acc/top1: 0.5208  acc/top5: 0.7874  acc/mean1: 0.1000  data_time: 0.0012  time: 0.0140
# 05/09 09:11:51 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:12:23 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:12:54 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:13:25 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:13:27 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:13:27 - mmengine - INFO - Epoch(train) [16][4005/4005]  lr: 4.4775e-03  eta: 0:28:11  time: 0.0314  data_time: 0.0020  memory: 212  grad_norm: 0.4955  loss: 0.9699  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.9699
# 05/09 09:13:56 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:14:26 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:14:57 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:15:28 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:15:30 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:15:30 - mmengine - INFO - Epoch(train) [17][4005/4005]  lr: 3.9606e-03  eta: 0:26:11  time: 0.0294  data_time: 0.0016  memory: 212  grad_norm: 0.5096  loss: 0.9994  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.9994
# 05/09 09:15:58 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:16:29 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:17:00 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:17:31 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:17:34 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:17:34 - mmengine - INFO - Epoch(train) [18][4005/4005]  lr: 3.4550e-03  eta: 0:24:11  time: 0.0320  data_time: 0.0020  memory: 212  grad_norm: 0.5271  loss: 1.0312  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.0312
# 05/09 09:18:02 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:18:33 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:19:03 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:19:34 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:19:37 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:19:37 - mmengine - INFO - Epoch(train) [19][4005/4005]  lr: 2.9664e-03  eta: 0:22:11  time: 0.0302  data_time: 0.0016  memory: 212  grad_norm: 0.5482  loss: 1.0656  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.0656
# 05/09 09:20:05 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:20:36 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:21:07 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:21:38 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:21:41 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:21:41 - mmengine - INFO - Epoch(train) [20][4005/4005]  lr: 2.5001e-03  eta: 0:20:11  time: 0.0300  data_time: 0.0017  memory: 212  grad_norm: 0.5728  loss: 1.1029  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.1029
# 05/09 09:21:41 - mmengine - INFO - Saving checkpoint at 20 epochs
# 05/09 09:22:05 - mmengine - INFO - Epoch(val) [20][1703/1703]    acc/top1: 0.5208  acc/top5: 0.7874  acc/mean1: 0.1000  data_time: 0.0012  time: 0.0140
# 05/09 09:22:33 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:23:04 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:23:35 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:24:06 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:24:09 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:24:09 - mmengine - INFO - Epoch(train) [21][4005/4005]  lr: 2.0612e-03  eta: 0:18:11  time: 0.0300  data_time: 0.0017  memory: 212  grad_norm: 0.6001  loss: 1.1426  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.1426
# 05/09 09:24:37 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:25:08 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:25:39 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:26:10 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:26:13 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:26:13 - mmengine - INFO - Epoch(train) [22][4005/4005]  lr: 1.6544e-03  eta: 0:16:10  time: 0.0310  data_time: 0.0018  memory: 212  grad_norm: 0.6290  loss: 1.1841  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.1841
# 05/09 09:26:41 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:27:13 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:27:44 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:28:15 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:28:18 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:28:18 - mmengine - INFO - Epoch(train) [23][4005/4005]  lr: 1.2844e-03  eta: 0:14:10  time: 0.0309  data_time: 0.0018  memory: 212  grad_norm: 0.6575  loss: 1.2251  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.2251
# 05/09 09:28:46 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:29:17 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:29:49 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:30:19 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:30:23 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:30:23 - mmengine - INFO - Epoch(train) [24][4005/4005]  lr: 9.5499e-04  eta: 0:12:09  time: 0.0308  data_time: 0.0019  memory: 212  grad_norm: 0.6828  loss: 1.2616  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.2616
# 05/09 09:30:50 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:31:22 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:31:53 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:32:24 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:32:28 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:32:28 - mmengine - INFO - Epoch(train) [25][4005/4005]  lr: 6.6994e-04  eta: 0:10:08  time: 0.0313  data_time: 0.0019  memory: 212  grad_norm: 0.7006  loss: 1.2854  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.2854
# 05/09 09:32:28 - mmengine - INFO - Saving checkpoint at 25 epochs
# 05/09 09:32:53 - mmengine - INFO - Epoch(val) [25][1703/1703]    acc/top1: 0.5208  acc/top5: 0.7874  acc/mean1: 0.1000  data_time: 0.0012  time: 0.0140
# 05/09 09:33:21 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:33:52 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:34:23 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:34:54 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:34:59 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:34:59 - mmengine - INFO - Epoch(train) [26][4005/4005]  lr: 4.3233e-04  eta: 0:08:07  time: 0.0315  data_time: 0.0019  memory: 212  grad_norm: 0.7044  loss: 1.2819  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.2819
# 05/09 09:35:26 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:35:57 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:36:29 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:37:00 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:37:05 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:37:05 - mmengine - INFO - Epoch(train) [27][4005/4005]  lr: 2.4476e-04  eta: 0:06:05  time: 0.0306  data_time: 0.0018  memory: 212  grad_norm: 0.6878  loss: 1.2376  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.2376
# 05/09 09:37:32 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:38:04 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:38:35 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:39:07 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:39:12 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:39:12 - mmengine - INFO - Epoch(train) [28][4005/4005]  lr: 1.0929e-04  eta: 0:04:04  time: 0.0314  data_time: 0.0020  memory: 212  grad_norm: 0.6572  loss: 1.1721  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.1721
# 05/09 09:39:39 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:40:10 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:40:42 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:41:14 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:41:19 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:41:19 - mmengine - INFO - Epoch(train) [29][4005/4005]  lr: 2.7404e-05  eta: 0:02:02  time: 0.0310  data_time: 0.0019  memory: 212  grad_norm: 0.6345  loss: 1.1280  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.1280
# 05/09 09:41:46 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:42:17 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:42:49 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:43:20 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:43:25 - mmengine - INFO - Exp name: ciis_not-multi_20240509_083953
# 05/09 09:43:25 - mmengine - INFO - Epoch(train) [30][4005/4005]  lr: 1.7092e-12  eta: 0:00:00  time: 0.0323  data_time: 0.0021  memory: 212  grad_norm: 0.6275  loss: 1.1146  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 1.1146
# 05/09 09:43:25 - mmengine - INFO - Saving checkpoint at 30 epochs
# 05/09 09:43:49 - mmengine - INFO - Epoch(val) [30][1703/1703]    acc/top1: 0.5208  acc/top5: 0.7939  acc/mean1: 0.1000  data_time: 0.0012  time: 0.0139

# %% [markdown]
# ## Training from python
